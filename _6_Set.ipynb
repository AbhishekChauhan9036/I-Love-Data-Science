# %%
a = set()

# %%
type(a)
# Out:
# set

# %%
s = {4,5,6,7,7,1,2,9,4,0}

# %%
s
# Out:
# {0, 1, 2, 4, 5, 6, 7, 9}

# %%
set1 = {1, 2, 3, 4}
set2 = {3, 4 , 5, 6}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set2
# Out:
# {3, 4, 5, 6}

# %%
set1.intersection(set2)
# Out:
# {3, 4}
