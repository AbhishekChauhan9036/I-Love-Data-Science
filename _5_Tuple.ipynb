# %%
e = ()

# %%
e
# Out:
# ()

# %%
type(e)
# Out:
# tuple

# %%
t = (1,2,3,4,5)  #Immutable

# %%
len(t)
# Out:
# 5

# %%
t[2]
# Out:
# 3

# %%
# Packing 
person = ("Amit", 32, "Assistant Professor")

# Unpacking
name , age , designation = person

# %%
name
# Out:
# 'Amit'

# %%
age
# Out:
# 32

# %%
designation
# Out:
# 'Assistant Professor'

# %%
tup = (1,2,3,4,5,6,7,1,1,1,1,1)
tup.count(1)
# Out:
# 6
