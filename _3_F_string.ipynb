# %%
name = "Abhishek Chauhan"
age = 22
address = "Ballia"

# %%
print(f"My Name is {name} and I'm {age} year old and I'm from {address}")
# Out:
# My Name is Abhishek Chauhan and I'm 22 year old and I'm from Ballia

# %%
print("My Name is {} and I am {} year old.".format(name , age))
# Out:
# My Name is Abhishek Chauhan and I am 22 year old.

# %%
print(f"{'Python':<10}") #Left-align
print(f"{'Python':>10}") #Right-align
print(f"{'Python':^10}") #Center-align
# Out:
# Python
#     Python
#   Python
