# %%
l = [3, 4, 5, 1]

# %%
l[2] = 7

# %%
l
# Out:
# [3, 4, 7, 1]

# %%
l.append(9) #Mutuble

# %%
l
# Out:
# [3, 4, 7, 1, 9, 9]

# %%
l2 = [ 13 , 19]

# %%
l.extend(l2)

# %%
l
# Out:
# [3, 4, 7, 1, 9, 9, 13, 19]
