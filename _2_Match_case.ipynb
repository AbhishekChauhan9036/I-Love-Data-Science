# %%
code = 500

# %%
match code:
    case 200:
        print("Response Ok")
    case 400:
        print("Bad Response")
    case 404:
        print("Not Found")
    case _:
        print("Nothing Match")
# Out:
# Nothing Match
