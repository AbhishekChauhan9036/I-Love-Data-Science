# %%
a = 5

# %%
b = 10

# %%
a + b
# Out:
# 15

# %%
name = "Abhishek"

# %%
print(name)
# Out:
# Abhishek

# %%
fname = "Abhishek"
lname = "Chauhan"
print(fname + lname)
# Out:
# AbhishekChauhan

# %%
print(type(fname))
# Out:
# <class 'str'>

# %%
type(lname)
# Out:
# str
